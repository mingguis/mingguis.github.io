# %% [markdown]
# # Motivation
# Build a movie recommendation system that utilizes consumer reviews across multiple popular movie review websites. Not a single review website has the dominating power so that the recommender system has a distributed built-in.
#
# a **Recommendation System** is a filtration program whose prime goal is to predict the “rating” or “preference” of a user towards a domain-specific item or item, here a movie.
#
# Different filtration strategies include: content based filtering and collaborative filtering.
# ![[Pasted image 20220619212612.png]]
# -   #### Content-based Filtering
#
#     This filtration strategy is based on the data provided about the items. The algorithm recommends products that are **similar** to the ones that a user has liked in the **past**. This similarity (generally cosine similarity) is computed from the data we have about the items as well as the user’s past preferences.
#
#     For example, if a user likes movies such as ‘The Prestige’ then we can recommend him the movies of ‘Christian Bale’ or movies with the genre ‘Thriller’ or maybe even movies directed by ‘Christopher Nolan’.So what happens here the recommendation system checks the past preferences of the user and find the film “The Prestige”, then tries to find similar movies to that using the information available in the database such as the lead actors, the director, genre of the film, production house, etc and based on this information find movies similar to “The Prestige”.
#
#     #### Disadvantages
#
#     1.  Different products do not get much **exposure** to the user.
#     2.  Businesses cannot be expanded as the user does not try different types of products.
#
# -   #### Collaborative Filtering
#
#     This filtration strategy is based on the combination of the user’s behavior and comparing and contrasting that with **other users’** behavior in the database. The history of **all users** plays an important role in this algorithm. The main difference between content-based filtering and collaborative filtering that in the latter, the **interaction of all users with the items** influences the recommendation algorithm while for content-based filtering only the **concerned user’s data** is taken into account.
#
#     There are multiple ways to implement collaborative filtering but the main concept to be grasped is that in collaborative filtering **multiple** user’s data influences the outcome of the recommendation. and doesn’t depend on **only one user’s data** for modeling.
#
#     There are 2 types of collaborative filtering algorithms:
#
#     -   #### User-based Collaborative filtering
#
#         The basic idea here is to find users that have **similar past preference patterns** as the user ‘A’ has had and then recommending him or her items liked by those similar users which ‘A’ has not encountered yet. This is achieved by making a matrix of items each user has rated/viewed/liked/clicked depending upon the task at hand, and then computing the similarity score between the users and finally recommending items that the concerned user isn’t aware of but users similar to him/her are and liked it.
#
#         For example, if the user ‘A’ likes ‘Batman Begins’, ‘Justice League’ and ‘The Avengers’ while the user ‘B’ likes ‘Batman Begins’, ‘Justice League’ and ‘Thor’ then they have similar interests because we know that these movies belong to the super-hero genre. So, there is a high probability that the user ‘A’ would like ‘Thor’ and the user ‘B’ would like The Avengers’.
#
#         Disadvantages
#
#         1.  People are **fickle-minded** i.e their taste change from time to time and as this algorithm is based on user similarity it may pick up initial similarity patterns between 2 users who after a while may have completely different preferences.
#         2.  There are many **more users than items** therefore it becomes very difficult to maintain such large matrices and therefore needs to be recomputed very regularly.
#         3.  This algorithm is very susceptible to **shilling attacks** where fake users profiles consisting of biased preference patterns are used to manipulate key decisions.
#
#
#     -   #### Item-based Collaborative Filtering
#
#         The concept in this case is to **find similar movies instead of similar users** and then recommending similar movies to that ‘A’ has had in his/her past preferences. This is executed by finding every pair of items that were rated/viewed/liked/clicked by the same user, then measuring the similarity of those rated/viewed/liked/clicked across all user who rated/viewed/liked/clicked both, and finally recommending them based on similarity scores.
#
#         Here, for example, we take 2 movies ‘A’ and ‘B’ and check their ratings by all users who have rated both the movies and based on the similarity of these ratings, and based on this rating similarity by users who have rated both we find similar movies. So if most common users have rated ‘A’ and ‘B’ both similarly and it is highly probable that ‘A’ and ‘B’ are similar, therefore if someone has watched and liked ‘A’ they should be recommended ‘B’ and vice versa.
#
#         #### Advantages over User-based Collaborative Filtering
#
#         1.  Unlike people’s taste, **movies don’t change**.
#         2.  There are usually a lot **fewer items than people,** therefore easier to maintain and compute the matrices.
#         3.  Shilling attacks are much harder because **items cannot be faked**.
#
# #### Disadvantages
#
# 1.  Different products do not get much **exposure** to the user.
# 2.  Businesses cannot be expanded as the user does not try different types of products.
#
#
#
# The genre approach provides the most effective means for understanding, analyzing and appreciating the Hollywood cinema. Taking into account not only the formal and aesthetic aspects of feature filmmaking, but various other cultural aspects as well, the genre approach treats movie production as a dynamic process of exchange between the film industry and its audience. This process, embodied by the Hollywood studio system, has been sustained primarily through genres, those popular narrative formulas like the Western, musical and gangster film, which have dominated the screen arts throughout this century.
#
# Connect to [[Brett Danaher]]'s research background, using similar designs as [[Erik Broynjofsson job2vec]] and [[Paramvver Dhillon news2vec]].
#
# MovieLens Movie Catetgories:
#  - 0. Classic, masterpiece, quotable
#  - 1. Action, fun movie, special effects
#  - 2. dramatic, good acting, intense
#  - 3. blood, dark humor, social commentary
#  - 4. computer animation, good versus evil, mythology
#  - 5. chick flick, feel good, touching
#
#
# cannot share emotions (Tik Tok, short videos, selfie. retrospect, egoistic, self-centered, egocentric, swollen-headed, conceited.
#
#
# Movie, book, music -- entertainment 1.0, Uni-Directal Media
# Games, Communities -- entertainment 2.0, Bi-Directional Media, interaction, engagement. Material Re-Organization.
#
#
# It is easy for media to make blockbusters ubiquitous, but outgunned for things that are only for a small group of people.
#
# Unbiased recommendation. Inequality.
#
# Common Interest -> Collective Preferences.
#
#
# Create a different type of recommender that learns the unique relationship without traditional user-item data available.
#
# W2V is a shadow neural network that predicts a word given its context words in a sentence. Under a particular architecture.
#
# After this shadow neural network is trained, you have a by-product that is the vector representation of all words. You can add, substract (multiply???) these vectors and uncover analogous relationships. The same thing might also be applied to movies.
#
# What is the company, Tim, Will, Jon built on film recommendation ML algorithm??? Back to the 2000s??  ---- The Savage Beast Technologies company.
#
#
# “ the prototype of the Music Genome—an enhanced Excel spreadsheet with about fifty musical “genes” analyzing about seven hundred and fifty songs; the genes were, in truth, a bit naïve: tempo—fast to slow; harmony—major or minor; danceable—low to high, plus a bunch of instruments. ”
#
# It is all about granuality/ How many points are you going to assign to each category?
#
# why 3 instead of 5? why 5 instead of 10? why 10 instead of 1000? ? generality vs personality.
#
# # More to research
#
# [] Garage.com, venture capital for Pandora.
#
# [] the Music Genome Project (MGP). How many genes are there now for all the musci industry？
#
# [] Katchdata's Movie Genome Project (MGP2??)
#
#
#
# # Analogies
# words -> movies
# context
# 			-> watch sequence???? What if we don't have the watch sequences??
# 			-> movie tags??? losing position importance
# 			-> Or leave out movie contexts, only use the intrinsic word vector space?
#
#  What are the hidden assumptions of all these?
#
#  How to define taste of movies??
#
#  How do them difffer from those of music?
#
#  movie-cal taste means that“
#  On a surface level, one’s “musical taste” refers to the music that aligns with one’s personal preferences—and hence the commonly used term “musical preferences” as a more formal equivalent, particularly in academic literature.”
#
#
# New York Times, The paradigm is shifting.
#
# What does this mean to traditional distribution mode? Offline theaters may not have bargaining powers any more. Like the old music disc companies???
#
#
# move our focus from feature-based learning to relation-based learning and more specifically, embeddings, because relations of tuples can be modeled efficiently even with sparse input data. More precisely, we treat each movie as a vertice in a graph that has edges to other vertices (movies) that model arbitrary relations between those movies.
#
# ## Graph NNs Approach
#
# https://raberrytv.wordpress.com/2015/12/31/movie2vec-adapting-word-embeddings-for-movies/
#
#
#
# # Previous Movie2Vecs
#
#
#
#
# | Title         | Link                                                             | Description | Vector Size | Methods| Date | Poster |
# | ------------- | ---------------------------------------------------------------- | ----------- | ----------- | ------ | ---- | ---- |
# | Plot2Vec      | [WordPress](https://movie2vec.wordpress.com/2016/05/14/movie2vec-feature-extraction-from-wikipedia-plot-summaries/) | Use Google's Word2Vec framework and texts of plot summaries of movies on Wikipedia to predict genres. | 15 words | W2V |2016-05-14| ![[WikipediaPlotWordEmbeddings.png]] |
# | Tag2Vec       | [LinkedIn](https://www.linkedin.com/pulse/movie2vec-arithmetic-movie-recommender-nikhil-makaram/) [GitHub](https://github.com/nikasso/movie2vec) | Vecotr Representation of Tags on MovieLens | thousands of words |  W2V | 2017-09-16 | ![[LinkedIn2017.png]] |
# | Anime2Vec     | [Mangaki GitHub](https://github.com/mangaki/notebooks) | . |  unclear | BALSE |2017| ![[]] |
# | WatchSeq2Vec  | [Springer](https://link.springer.com/chapter/10.1007/978-3-030-04726-9_16) | . |  unclear | . | 2018-12-29 | ![[]] |
# | X2Vec         | [GitHub](https://github.com/mangaki/notebooks) | . |  unclear | . | 2022 | ![[]] |
# | X2Vec         | [GitHub](https://github.com/mangaki/notebooks) | . |  unclear | . | 2022 | ![[]] |
# | X2Vec         | [GitHub](https://github.com/mangaki/notebooks) | . |  unclear | . | 2022 | ![[]] |
#
#
#
# # Quantatitive Study of Movie Box Sales, Box Office Performance (BOP)
#
# | Themes |  Authors |
# |---------|----------|
# | _Audience reviews_ | Dellarocas, Zhang, and Awad ([2007](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)); Duan, Gu, and Whinston ([2008](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)); Chintagunta, Gopinath, and Venkataraman ([2010](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)) |
# | _Professional critics_ | Eliashberg and Shugan ([1997](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)); Basuroy, Chatterjee, and Ravid ([2003](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)); Boatwright, Basuroy, and Kamakura ([2007](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)) |
# | _Word-of-mouth (WoM)_ | Liu ([2006](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)); Moul ([2007](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)); Ding et al. ([2017](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)) |
# | _Volume versus valence_ | Flanagin and Metzger ([2013](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)); Kim, Yoon, and Choi ([2019](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)) |
# | _Reviews between arthouse and mainstream movies_ | Gemser, Van Oostrum, and Leenders ([2007](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)) |
# | _Professional critics versus online reviews_ | Chakravarty, Liu, and Mazumdar ([2010](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)); Kim, Park, and Park ([2013](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)); Basuroy et al. ([2020](https://www.tandfonline.com/doi/full/10.1080/10632921.2021.2018375#)) |
# | _Reviews on different genre_ | Wanderer ([2011](https://doi.org/10.2190/EM.29.1.c)) |
#
# # Datasets
#
# ### Context
#
# These files contain metadata for all 45,000 movies listed in the Full MovieLens Dataset. The dataset consists of movies released on or before July 2017. Data points include cast, crew, plot keywords, budget, revenue, posters, release dates, languages, production companies, countries, TMDB vote counts and vote averages.
#
# This dataset also has files containing 26 million ratings from 270,000 users for all 45,000 movies. Ratings are on a scale of 1-5 and have been obtained from the official GroupLens website.
#
# ### Content
#
# This dataset consists of the following files:
#
# **movies_metadata.csv:** The main Movies Metadata file. Contains information on 45,000 movies featured in the Full MovieLens dataset. Features include posters, backdrops, budget, revenue, release dates, languages, production countries and companies.
#
# **keywords.csv:** Contains the movie plot keywords for our MovieLens movies. Available in the form of a stringified JSON Object.
#
# **credits.csv:** Consists of Cast and Crew Information for all our movies. Available in the form of a stringified JSON Object.
#
# **links.csv:** The file that contains the TMDB and IMDB IDs of all the movies featured in the Full MovieLens dataset.
#
# **links_small.csv:** Contains the TMDB and IMDB IDs of a small subset of 9,000 movies of the Full Dataset.
#
# **ratings_small.csv:** The subset of 100,000 ratings from 700 users on 9,000 movies.
#
# The Full MovieLens Dataset consisting of 26 million ratings and 750,000 tag applications from 270,000 users on all the 45,000 movies in this dataset can be accessed [here](https://grouplens.org/datasets/movielens/latest/)
#
# ### Acknowledgements
#
# This dataset is an ensemble of data collected from TMDB and GroupLens.
# The Movie Details, Credits and Keywords have been collected from the TMDB Open API. This product uses the TMDb API but is not endorsed or certified by TMDb. Their API also provides access to data on many additional movies, actors and actresses, crew members, and TV shows. You can try it for yourself [here](https://www.themoviedb.org/documentation/api).
#
# The Movie Links and Ratings have been obtained from the Official GroupLens website. The files are a part of the dataset available [here](https://grouplens.org/datasets/movielens/latest/)
#
#
# ### Inspiration
#
# This dataset was assembled as part of my second Capstone Project for Springboard's [Data Science Career Track](https://www.springboard.com/workshops/data-science-career-track). I wanted to perform an extensive EDA on Movie Data to narrate the history and the story of Cinema and use this metadata in combination with MovieLens ratings to build various types of Recommender Systems.
#
# Both my notebooks are available as kernels with this dataset: [The Story of Film](https://www.kaggle.com/rounakbanik/the-story-of-film) and [Movie Recommender Systems](https://www.kaggle.com/rounakbanik/movie-recommender-systems)
#
# Some of the things you can do with this dataset:
# Predicting movie revenue and/or movie success based on a certain metric. What movies tend to get higher vote counts and vote averages on TMDB? Building Content Based and Collaborative Filtering Based Recommendation Engines.
#
#
# # Theoretical background
#
# **“Nobody knows anything… Not one person in the entire motion picture field knows for a certainty what's going to work [at the box office].”**
#
# - William Goldman, a two-time Oscar-winning screenwriter
#
# ## conceptual model
#
# from IS construct perspective, use movie meta data and platform review data to reveal consumer's real preference.
#
#
#
# # Empirical Design
#
# ## Lab Experiment
#
# Find two similar groups of students who are interested in the movie industry.
#
# One is from the University of California, Irvine and the other is from Chapman University.
#
# One is recommended by the Collaborative Filtering algorithm and the other is recommended by the Content Based algorithm.

# %% [markdown]
# # Exploring Movie Datasets
#
# # 0. Executive Summary
# We use various data sources to build our movie2vec model. 1. Background is using IMDb for general understanding of the Movie industry. We plot the distribution of movie production years, director ages, movie ratings. 2. Movielens is using user-movie watch sequence to model a distributed representation of movies, i.e. Movie2Vec representations. We use the movie2vec model to predict the movie ratings of a user and recommend movies to a user.

# %%
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# C:\Users\mgu3\AppData\Local\Temp\ipykernel_14364\3777615979.py:1: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %% [markdown]
# # 1. Background
#
# <!-- <span style="font-family:Georgia;font-size:18px;line-height:1.5"> -->
#
# Use unique movie review data to build a ```Movie2Vec``` recommender system.
#
#
#
# <!-- </style> -->

# %%
# %matplotlib inline


import pandas as pd
import gzip


pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_eng_float_format(accuracy=3, use_eng_prefix=True)
pd.set_option('display.float_format', lambda x: '%.3f' % x)


from sklearn.feature_extraction.text import CountVectorizer

import pycountry




import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib import rcParams
rcParams['figure.figsize'] = 12, 12

import warnings
warnings.filterwarnings('ignore')

import sweetviz as sv

import sklearn
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB, MultinomialNB
from sklearn.svm import SVC
from sklearn import model_selection
from sklearn.model_selection import train_test_split, GridSearchCV, \
    cross_val_score, RepeatedStratifiedKFold, StratifiedKFold
from sklearn.metrics import plot_precision_recall_curve, classification_report,\
    plot_confusion_matrix, plot_roc_curve

# %%
import sys
print(sys.version)
# Out:
# 3.9.7 (default, Sep 16 2021, 16:59:28) [MSC v.1916 64 bit (AMD64)]

# %%
def show_values(axs, orient="v", space=.01, precision=2):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = ('{:.'+str(precision)+'f}').format(p.get_height())
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = ('{:.'+str(precision)+'f}').format(p.get_width())
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)

# %% [markdown]
# # 1. IMDb
#
# <!-- <span style="font-family:Georgia;font-size:18px;line-height:1.5"> -->
# IMDb’s dataset is available online and refreshed daily. This version is retrieved on Feb 8th, 2022. Each dataset is contained in a gzipped, tab-separated-values (TSV) formatted file in the UTF-8 character set. The first line in each file contains headers that describe what is in each column. A ‘\N’ is used to denote that a particular field is missing or null for that title/name.
# https://www.imdb.com/interfaces/. The available datasets are as follows:
# <!-- </span> -->

# %% [markdown]
# ## AKAS - Movie shown in these regions
#
# #### title.akas.tsv.gz - Contains the following information for titles:
#  - titleId (string) - a tconst, an alphanumeric unique identifier of the title.
#  - ordering (integer) – a number to uniquely identify rows for a given titleId.
#  - title (string) – the localized title.
#  - region (string) - the region for this version of the title.
#  - language (string) - the language of the title.
#  - types (array) - Enumerated set of attributes for this alternative title. One or more of the following: "alternative", "dvd", "festival", "tv", "video", "working", "original", "imdbDisplay". New values may be added in the future without warning.
#  - attributes (array) - Additional terms to describe this alternative title, not enumerated.
#  - isOriginalTitle (boolean) – 0: not original title; 1: original title.

# %%
with gzip.open('../01PrimaryData/IMDb/title.akas.tsv.gz') as f:
    akas = pd.read_csv(f, sep='\t',na_values='\\N', quoting=3)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  \
# 0  tt0000001         1                 Карменсіта     UA      NaN
# 1  tt0000001         2                 Carmencita     DE      NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN
# 4  tt0000001         5                 Карменсита     RU      NaN
#
#          types     attributes  isOriginalTitle
# 0  imdbDisplay            NaN            0.000
# 1          NaN  literal title            0.000
# 2  imdbDisplay            NaN            0.000
# 3  imdbDisplay            NaN            0.000
# 4  imdbDisplay            NaN            0.000

# %%
akas.describe(include='all')
# Out:
#           titleId  ordering          title    region  language        types  \
# count    31187805   31.188M       31187801  29276222  25082539      5234132
# unique    6170008       NaN        3902885       246       104           23
# top     tt0168366       NaN  Episodio #1.1        FR        ja  imdbDisplay
# freq          177       NaN          85232   3704075   3574649      3172290
# mean          NaN     4.028            NaN       NaN       NaN          NaN
# std           NaN     3.496            NaN       NaN       NaN          NaN
# min           NaN     1.000            NaN       NaN       NaN          NaN
# 25%           NaN     2.000            NaN       NaN       NaN          NaN
# 50%           NaN     4.000            NaN       NaN       NaN          NaN
# 75%           NaN     6.000            NaN       NaN       NaN          NaN
# max           NaN   177.000            NaN       NaN       NaN          NaN
#
#                   attributes  isOriginalTitle
# ...

# %%
colors = sns.color_palette()

# %%
sv.analyze(akas.drop(['titleId'],axis=1), 'region').show_notebook(layout='widescreen')

# %%
country_counts = akas.region.value_counts()
country_names = [pycountry.countries.get(alpha_2=coun).name for coun in country_counts.drop(["XWW","XWG"]).index[:20]]
counts = country_counts.drop(["XWW","XWG"]).values[:20]

plt.figure(figsize=(24,12))
p1=sns.barplot(x=counts,y=country_names,orient="h")
plt.xlabel("Top 20 Regions with Most Title Aka's")

show_values(p1, "h", space=.01, precision=0)

# %% [markdown]
# ## BASICS - Basic information about the movie
#
# #### title.basics.tsv.gz - Contains the following information for titles:
#  - tconst (string) - alphanumeric unique identifier of the title.
#  - titleType (string) – the type/format of the title (e.g. movie, short, tvseries, tvepisode, video, etc).
#  - primaryTitle (string) – the more popular title / the title used by the filmmakers on promotional materials at the point of release.
#  - originalTitle (string) - original title, in the original language.
#  - isAdult (boolean) - 0: non-adult title; 1: adult title.
#  - startYear (YYYY) – represents the release year of a title. In the case of TV Series, it is the series start year.
#  - endYear (YYYY) – TV Series end year. for all other title types.
#  - runtimeMinutes – primary runtime of the title, in minutes.
#  - genres (string array) – includes up to three genres associated with the title.

# %%
with gzip.open('../01PrimaryData/IMDb/title.basics.tsv.gz') as f:
    basics = pd.read_csv(f, sep='\t', na_values='\\N', quoting=3)

# %%
# drop nan rows
basics = basics.dropna(subset=['titleType','startYear','runtimeMinutes'])
basics = basics[basics.titleType.isin(['movie','tvMovie'])]
basics = basics[basics.isAdult==0]
del basics['isAdult']

# %%
basics['startYear'] = basics['startYear'].astype(int, errors='ignore')
basics['endYear'] = basics['endYear'].astype(int, errors='ignore')
basics['runtimeMinutes'] = basics['runtimeMinutes'].astype(int, errors='ignore')
# basics['titleType'] = basics['titleType'].astype('category')
# basics['isAdult'] = basics['isAdult'].astype('category')
# basics['isAdult'].cat.categories = ['False', 'True']

# %%
# basics[~ basics['runtimeMinutes'].astype(str).fillna('').str.isnumeric()]
# basics[pd.to_numeric(basics.runtimeMinutes, errors='coerce').null()]

# %%
basics[basics.startYear.isnull()]
# Out:
# Empty DataFrame
# Columns: [tconst, titleType, primaryTitle, originalTitle, startYear, endYear, runtimeMinutes, genres]
# Index: []

# %%
basics.head(50)
# Out:
#          tconst titleType                                       primaryTitle  \
# 498   tt0000502     movie                                           Bohemios
# 570   tt0000574     movie                        The Story of the Kelly Gang
# 587   tt0000591     movie                                   The Prodigal Son
# 672   tt0000679     movie                     The Fairylogue and Radio-Plays
# 1172  tt0001184     movie                            Don Juan de Serrallonga
# 1273  tt0001285     movie                                  The Life of Moses
# 1485  tt0001498     movie                            The Battle of Trafalgar
# 1578  tt0001592     movie                               In the Prime of Life
# 1616  tt0001630     movie                                   Der fremde Vogel
# 1739  tt0001756     movie                              Lucha por la herencia
# 1773  tt0001790     movie               Les Misérables, Part 1: Jean Valjean
# ...

# %%
basics.describe(include='all')
# Out:
#            tconst titleType primaryTitle originalTitle  startYear  endYear  \
# count      459090    459090       459090        459090 459090.000    0.000
# unique     459090         2       409264        418312        NaN      NaN
# top     tt0000502     movie      Macbeth       Macbeth        NaN      NaN
# freq            1    368082           51            49        NaN      NaN
# mean          NaN       NaN          NaN           NaN   1994.360      NaN
# std           NaN       NaN          NaN           NaN     25.100      NaN
# min           NaN       NaN          NaN           NaN   1896.000      NaN
# 25%           NaN       NaN          NaN           NaN   1979.000      NaN
# 50%           NaN       NaN          NaN           NaN   2004.000      NaN
# 75%           NaN       NaN          NaN           NaN   2014.000      NaN
# max           NaN       NaN          NaN           NaN   2027.000      NaN
#
#         runtimeMinutes       genres
# ...

# %%
# basics.describe(include='all')
# Out:
#            tconst  titleType  primaryTitle originalTitle  isAdult  startYear  \
# count     8734057    8734057       8734049       8734049  8734057     8.734M
# unique    8734057         11       4055617       4075260        2        NaN
# top     tt0000001  tvEpisode  Episode #1.1  Episode #1.1    False        NaN
# freq            1    6538425         42648         42648  8463700        NaN
# mean          NaN        NaN           NaN           NaN      NaN     1.743k
# std           NaN        NaN           NaN           NaN      NaN    674.399
# min           NaN        NaN           NaN           NaN      NaN      0.000
# 25%           NaN        NaN           NaN           NaN      NaN     1.985k
# 50%           NaN        NaN           NaN           NaN      NaN     2.009k
# 75%           NaN        NaN           NaN           NaN      NaN     2.016k
# max           NaN        NaN           NaN           NaN      NaN     2.029k
#
#         endYear  runtimeMinutes   genres
# ...

# %% [markdown]
# ##### Movie Genres

# %%
temp = basics.genres.dropna()
vec = CountVectorizer(token_pattern='(?u)\\b[\\w-]+\\b', analyzer='word').fit(temp)
bag_of_genres = vec.transform(temp)
unique_genres =  vec.get_feature_names()
genres = pd.DataFrame(bag_of_genres.todense(),columns=unique_genres,index=temp.index)
sorted_genres_perc = 100*pd.Series(genres.sum()).sort_values(ascending=False)/genres.shape[0]

plt.figure(figsize=(24,12))
p2=sns.barplot(x=sorted_genres_perc.values,y=sorted_genres_perc.index,orient="h")
plt.xlabel("Genre Percentage of IMDb Movies (%)")

show_values(p2, "h", space=.01, precision=2)

# %%
# basics.describe(include='all')

# %% [markdown]
# ##### Title Genres

# %%
temp = basics.genres.dropna()
vec = CountVectorizer(token_pattern='(?u)\\b[\\w-]+\\b', analyzer='word').fit(temp)
bag_of_genres = vec.transform(temp)
unique_genres =  vec.get_feature_names()
genres = pd.DataFrame(bag_of_genres.todense(),columns=unique_genres,index=temp.index)
sorted_genres_perc = 100*pd.Series(genres.sum()).sort_values(ascending=False)/genres.shape[0]

# %%
plt.figure(figsize=(24,12))
sns.barplot(x=sorted_genres_perc.values,y=sorted_genres_perc.index,orient="h")
plt.xlabel("Genre Percentage of IMDb Titles (%)")

for i,count in enumerate(sorted_genres_perc.values):
    plt.text(count, i, round(count,2), va="center")

# %%
# now let's focus on only movies

akas = pd.merge(basics, akas, right_on='titleId', left_on='tconst')

# %%
akas.head(50)
# Out:
#        tconst titleType                    primaryTitle  \
# 0   tt0000502     movie                        Bohemios
# 1   tt0000502     movie                        Bohemios
# 2   tt0000574     movie     The Story of the Kelly Gang
# 3   tt0000574     movie     The Story of the Kelly Gang
# 4   tt0000574     movie     The Story of the Kelly Gang
# 5   tt0000574     movie     The Story of the Kelly Gang
# 6   tt0000574     movie     The Story of the Kelly Gang
# 7   tt0000574     movie     The Story of the Kelly Gang
# 8   tt0000574     movie     The Story of the Kelly Gang
# 9   tt0000574     movie     The Story of the Kelly Gang
# 10  tt0000574     movie     The Story of the Kelly Gang
# 11  tt0000574     movie     The Story of the Kelly Gang
# 12  tt0000591     movie                The Prodigal Son
# 13  tt0000591     movie                The Prodigal Son
# 14  tt0000591     movie                The Prodigal Son
# 15  tt0000679     movie  The Fairylogue and Radio-Plays
# ...

# %%
country_counts = akas.region.value_counts()
country_names = [pycountry.countries.get(alpha_2=coun).name for coun in country_counts.drop(["XWW","XWG"]).index[:20]]
counts = country_counts.drop(["XWW","XWG"]).values[:20]

plt.figure(figsize=(24,12))
sns.barplot(x=counts,y=country_names,orient="h")
plt.xlabel("Top 20 Regions with Most Movie Aka's")

for i,count in enumerate(counts):
    plt.text(count, i, count, va="center")

# %% [markdown]
# ## CREW - Directors and writers
#
# #### title.crew.tsv.gz – Contains the director and writer information for all the titles in IMDb. Fields include:
#  - tconst (string) - alphanumeric unique identifier of the title
#  - directors (array of nconsts) - director(s) of the given title
#  - writers (array of nconsts) – writer(s) of the given title

# %%
with gzip.open('../01PrimaryData/IMDb/title.crew.tsv.gz') as f:
    crew = pd.read_csv(f, sep='\t', na_values='\\N', quoting=3)

# %%
crew.head()
# Out:
#       tconst  directors writers
# 0  tt0000001  nm0005690      \N
# 1  tt0000002  nm0721526      \N
# 2  tt0000003  nm0721526      \N
# 3  tt0000004  nm0721526      \N
# 4  tt0000005  nm0005690      \N

# %%
crew.describe(include='all')
# Out:
#            tconst directors  writers
# count     8671097   8671097  8671097
# unique    8671097    840362  1162214
# top     tt0000001        \N       \N
# freq            1   3725519  4243163

# %% [markdown]
# ## EPISODE - TV Series episode information
# #### title.episode.tsv.gz – Contains the tv episode information. Fields include:
#  - tconst (string) - alphanumeric identifier of episode
#  - parentTconst (string) - alphanumeric identifier of the parent TV Series
#  - seasonNumber (integer) – season number the episode belongs to
#  - episodeNumber (integer) – episode number of the tconst in the TV series

# %%
with gzip.open('../01PrimaryData/IMDb/title.episode.tsv.gz') as f:
    episode = pd.read_csv(f, sep='\t', na_values='\\N', quoting=3)

# %%
episode.head()
# Out:
#       tconst parentTconst seasonNumber episodeNumber
# 0  tt0020666   tt15180956            1             2
# 1  tt0020829   tt15180956            1             1
# 2  tt0021166   tt15180956            1             3
# 3  tt0021612   tt15180956            2             2
# 4  tt0021655   tt15180956            2             5

# %%
episode.describe(include='all')
# Out:
#            tconst parentTconst seasonNumber episodeNumber
# count     6483931      6483931      6483931       6483931
# unique    6483931       168650          379         15715
# top     tt0020666   tt12164062            1            \N
# freq            1        17093      3198158       1383143

# %% [markdown]
# ## NAME - People names and professions
#
# #### name.basics.tsv.gz – Contains the following information for people names:
#  - nconst (string) - alphanumeric unique identifier of the name/person.
#  - primaryName (string)– name by which the person is most often credited.
#  - birthYear – in YYYY format.
#  - deathYear – in YYYY format if applicable, else .
#  - primaryProfession (array of strings)– the top-3 professions of the person.
#  - knownForTitles (array of tconsts) – titles the person is known for.

# %%
with gzip.open('../01PrimaryData/IMDb/name.basics.tsv.gz') as f:
    name = pd.read_csv(f, sep='\t', na_values='\\N', quoting=3)

# %%
# name = pd.read_csv('../01PrimaryData/IMDb/name.tsv', sep='\t', na_values='\\N', quoting=3)

# %%
name['birthYear'] = name['birthYear'].astype(int, errors='ignore')

# %%
name['deathYear'] = name['deathYear'].astype(int, errors='ignore')

# %%
name.head()
# Out:
#       nconst      primaryName  birthYear  deathYear  \
# 0  nm0000001     Fred Astaire   1899.000   1987.000
# 1  nm0000002    Lauren Bacall   1924.000   2014.000
# 2  nm0000003  Brigitte Bardot   1934.000        NaN
# 3  nm0000004     John Belushi   1949.000   1982.000
# 4  nm0000005   Ingmar Bergman   1918.000   2007.000
#
#                      primaryProfession  \
# 0       soundtrack,actor,miscellaneous
# 1                   actress,soundtrack
# 2  actress,soundtrack,music_department
# 3              actor,soundtrack,writer
# 4                writer,director,actor
#
#                             knownForTitles
# 0  tt0031983,tt0053137,tt0050419,tt0072308
# 1  tt0071877,tt0038355,tt0037382,tt0117057
# 2  tt0049189,tt0057345,tt0054452,tt0056404
# 3  tt0077975,tt0078723,tt0080455,tt0072562
# 4  tt0083922,tt0069467,tt0050986,tt0060827

# %%
name.tail()
# Out:
#              nconst         primaryName  birthYear  deathYear  \
# 11446410  nm9993714   Romeo del Rosario        NaN        NaN
# 11446411  nm9993716       Essias Loberg        NaN        NaN
# 11446412  nm9993717  Harikrishnan Rajan        NaN        NaN
# 11446413  nm9993718         Aayush Nair        NaN        NaN
# 11446414  nm9993719          Andre Hill        NaN        NaN
#
#                             primaryProfession                   knownForTitles
# 11446410  animation_department,art_department  tt14069590,tt11657662,tt2455546
# 11446411                                  NaN                              NaN
# 11446412                      cinematographer                        tt8736744
# 11446413                      cinematographer                              NaN
# 11446414                                  NaN                              NaN

# %%
name.describe(include='all')
# Out:
#            nconst primaryName  birthYear  deathYear primaryProfession  \
# count    11446415    11446415   545.381k   198.934k           9023564
# unique   11446415     8937691        NaN        NaN             20692
# top     nm0000001        Alex        NaN        NaN             actor
# freq            1         346        NaN        NaN           2046179
# mean          NaN         NaN     1.952k     1.991k               NaN
# std           NaN         NaN     34.604     34.229               NaN
# min           NaN         NaN      4.000     17.000               NaN
# 25%           NaN         NaN     1.930k     1.977k               NaN
# 50%           NaN         NaN     1.958k     1.999k               NaN
# 75%           NaN         NaN     1.978k     2.012k               NaN
# max           NaN         NaN     2.021k     2.022k               NaN
#
#        knownForTitles
# count         9424944
# unique        4758525
# top         tt0123338
# freq             8399
# ...

# %%
name.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 9023564 entries, 0 to 11446413
# Data columns (total 6 columns):
#  #   Column             Dtype
# ---  ------             -----
#  0   nconst             object
#  1   primaryName        object
#  2   birthYear          float64
#  3   deathYear          float64
#  4   primaryProfession  object
#  5   knownForTitles     object
# dtypes: float64(2), object(4)
# memory usage: 481.9+ MB

# %%
name = name[~name['primaryProfession'].isna()]
directorname = name[name['primaryProfession'].str.contains('director')]
writername = name[name['primaryProfession'].str.contains('writer')]
actorname = name[name['primaryProfession'].str.contains('actor')]
actressname = name[name['primaryProfession'].str.contains('actress')]

# %%
decades=[1800, 1900, 1910, 1920, 1930, 1940, 1950, 1960, 1970, 1980, 1990, 2000, 2010, 2020, 2030]
_, axes = plt.subplots(nrows=2, ncols=2, figsize=(24, 24))

out = pd.cut(directorname.birthYear, bins=decades, include_lowest=False)
p = sns.barplot(ax=axes[0,0],x=out.value_counts(sort=False), y=out.cat.categories , orient="h")
axes[0,0].set_ylabel("Director Birth Decades")
axes[0,0].set_xlabel("Number of Directors")
axes[0,0].set_title("Director Birth Year Distribution")
show_values(p, orient="h", space=.01, precision=0)


out = pd.cut(writername.birthYear, bins=decades, include_lowest=False)
p = sns.barplot(ax=axes[0,1],x=out.value_counts(sort=False), y=out.cat.categories , orient="h")
axes[0,1].set_ylabel("Writer Birth Decades")
axes[0,1].set_xlabel("Number of Writers")
axes[0,1].set_title("Writer Birth Year Distribution")
show_values(p, orient="h", space=.01, precision=0)

out = pd.cut(actorname.birthYear, bins=decades, include_lowest=False)
p = sns.barplot(ax=axes[1,0],x=out.value_counts(sort=False), y=out.cat.categories , orient="h")
axes[1,0].set_ylabel("Actor Birth Decades")
axes[1,0].set_xlabel("Number of Actors") 
axes[1,0].set_title("Actor Birth Year Distribution")
show_values(p, orient="h", space=.01, precision=0)

out = pd.cut(actressname.birthYear, bins=decades, include_lowest=False)
p = sns.barplot(ax=axes[1,1],x=out.value_counts(sort=False), y=out.cat.categories , orient="h")
axes[1,1].set_ylabel("Actress Birth Decades")
axes[1,1].set_xlabel("Number of Actresses")
axes[1,1].set_title("Actress Birth Year Distribution")
show_values(p, orient="h", space=.01, precision=0)

# %% [markdown]
# ## PRINCIPALS - Principals and their job categories
#
# #### title.principals.tsv.gz – Contains the principal cast/crew for titles:
#  - tconst (string) - alphanumeric unique identifier of the title.
#  - ordering (integer) – a number to uniquely identify rows for a given titleId.
#  - nconst (string) - alphanumeric unique identifier of the name/person.
#  - category (string) - the category of job that person was in.
#  - job (string) - the specific job title if applicable, else.
#  - characters (string) - the name of the character played if applicable, else.

# %%
with gzip.open('../01PrimaryData/IMDb/title.principals.tsv.gz') as f:
    principals = pd.read_csv(f, sep='\t', na_values='\\N', quoting=3)

# %%
principals.head()
# Out:
#       tconst  ordering     nconst         category                      job  \
# 0  tt0000001         1  nm1588970             self                       \N
# 1  tt0000001         2  nm0005690         director                       \N
# 2  tt0000001         3  nm0374658  cinematographer  director of photography
# 3  tt0000002         1  nm0721526         director                       \N
# 4  tt0000002         2  nm1335271         composer                       \N
#
#   characters
# 0   ["Self"]
# 1         \N
# 2         \N
# 3         \N
# 4         \N

# %%
principals.describe(include='all')
# Out:
#            tconst  ordering     nconst  category       job characters
# count    48712116   48.712M   48712116  48712116  48712116   48712116
# unique    7802078       NaN    4602937        12     36840    2554390
# top     tt1605991       NaN  nm0914844     actor        \N         \N
# freq           10       NaN      24062  10862975  40777885   24683293
# mean          NaN     4.580        NaN       NaN       NaN        NaN
# std           NaN     2.776        NaN       NaN       NaN        NaN
# min           NaN     1.000        NaN       NaN       NaN        NaN
# 25%           NaN     2.000        NaN       NaN       NaN        NaN
# 50%           NaN     4.000        NaN       NaN       NaN        NaN
# 75%           NaN     7.000        NaN       NaN       NaN        NaN
# max           NaN    10.000        NaN       NaN       NaN        NaN

# %% [markdown]
# ## RATINGS - Average ratings and number of votes
#
# #### title.ratings.tsv.gz – Contains the IMDb rating and votes information for titles:
#  - tconst (string) - alphanumeric unique identifier of the title.
#  - averageRating – weighted average of all the individual user ratings.
#  - numVotes - number of votes the title has received.

# %%
with gzip.open('../01PrimaryData/IMDb/title.ratings.tsv.gz') as f:
    ratings = pd.read_csv(f, sep='\t', low_memory=False, na_values='\\N', quoting=3)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001          5.700      1854
# 1  tt0000002          6.000       242
# 2  tt0000003          6.500      1622
# 3  tt0000004          6.000       157
# 4  tt0000005          6.200      2449

# %%
ratings.describe(include='all')
# Out:
#            tconst  averageRating  numVotes
# count     1212002         1.212M    1.212M
# unique    1212002            NaN       NaN
# top     tt0000001            NaN       NaN
# freq            1            NaN       NaN
# mean          NaN          6.924   997.824
# std           NaN          1.396   16.651k
# min           NaN          1.000     5.000
# 25%           NaN          6.200    11.000
# 50%           NaN          7.100    24.000
# 75%           NaN          7.900    94.000
# max           NaN         10.000    2.539M

# %% [markdown]
# More than 1 million rating entries (1,212,002). Average rating distribution shows a classic ```negative skewed distribution``` where the median is larger than mean. Vote count distribution is heavily clustered around small values (0–1000 votes). Therefore we need to do a bit extra to visualise this packed distribution

# %%
drating = dict(mean=ratings.averageRating.mean(),
              median=ratings.averageRating.median())
dvote = dict(mean=ratings.numVotes.mean(),
              median=ratings.numVotes.median())

plt.figure(figsize=(24,12))

plt.subplot(1,2,1)
ax1 = sns.distplot(ratings.averageRating,kde_kws=dict(bw=0.2))
ax1.axvline(x=drating["mean"],c=sns.color_palette("Set2")[1],label=f"mean={round(drating['mean'],2)}")
ax1.axvline(x=drating["median"],c=sns.color_palette("Set2")[2],label=f"median={round(drating['median'],2)}")
plt.legend()

plt.subplot(1,2,2)
ax2 = sns.distplot(ratings.numVotes,kde_kws=dict(bw=0.2))
ax2.axvline(x=dvote["mean"],c=sns.color_palette("Set2")[1],label=f"mean={round(dvote['mean'],2)}")
ax2.axvline(x=dvote["median"],c=sns.color_palette("Set2")[2],label=f"median={round(dvote['median'],2)}")
plt.legend()

plt.tight_layout()
plt.show()

# %% [markdown]
# Let’s try to use pandas.qcut function, which discretizes the variable into equal-sized buckets based on rank or based on sample quantiles. Let’s ```divide our data into 20 buckets and visualise```:
#
# - Over 93k samples (about 8%) have only 5 votes counted
# - Over 60k films have more than 1260 votes (these are the significant/popular films we are mostly interested in)

# %%
buckets = 20
plt.figure(figsize=(24,12))
bins = pd.qcut(ratings.numVotes,buckets,duplicates="drop").value_counts()
p=sns.barplot(x=bins.values,y=bins.index,orient="h")
p.set_xlabel("Number of Movies")
p.set_ylabel("Number of Votes")
show_values(p,orient="h",space=.01,precision=0)

# %% [markdown]
# we can also plot the distribution on a logarithmic scale. Since it is a count variable, it looks more like a Poisson distribution

# %%
plt.figure(figsize=(24,12))
ax=sns.distplot(ratings.numVotes,kde=False)
ax.set_ylabel("Count")
ax.set_yscale("log")

# %% [markdown]
# #### Counts per year

# %%
merged_temp = pd.merge(ratings,basics,on="tconst",how="left")
merged_temp = merged_temp[(merged_temp.startYear.notnull())&(merged_temp.startYear<2022)]
counts_yearly = merged_temp.groupby("startYear").agg({"averageRating":[np.median],
                                                     "numVotes":[np.sum,np.size,lambda x: np.sum(x)/np.size(x)]})

max_count_year = int(counts_yearly[("numVotes","sum")].idxmax())
max_year = int(counts_yearly[("numVotes","size")].idxmax())

plt.figure(figsize=(24,12))

plt.subplot(1,2,1)
ax =counts_yearly[("numVotes","size")].plot()
ax.annotate("WW I",xy=(1914,counts_yearly[("numVotes","size")].loc[1914]), xytext=(1918,2000), 
            arrowprops=dict(color="sandybrown",shrink=0.05,width=1))

ax.annotate("WW II",xy=(1939,counts_yearly[("numVotes","size")].loc[1939]), xytext=(1945,4000), 
            arrowprops=dict(color="sandybrown",shrink=0.05,width=1))

ax.annotate(max_year,xy=(max_year,counts_yearly[("numVotes","size")].max()), xytext=(1980,10000), 
            arrowprops=dict(color="sandybrown",shrink=0.05,width=1))

ax.annotate("COVID-19",xy=(2020,counts_yearly[("numVotes","size")].loc[2020]), xytext=(2020,4000), 
            arrowprops=dict(color="sandybrown",shrink=0.05,width=1))

plt.title("Total Number Films per Year",fontweight="bold")



plt.subplot(1,2,2)
ax =counts_yearly[("numVotes","sum")].plot()
ax.annotate(max_count_year,xy=(max_count_year,counts_yearly[("numVotes","sum")].max()),
            xytext=(1960,4e7),arrowprops=dict(shrink=0.05,color="sandybrown",width=2))
plt.title("Total Number of Voters per Year",fontweight="bold")
plt.show()

# %% [markdown]
# #### Average per by year

# %%
max_count_year_per_film = int(counts_yearly[("numVotes","<lambda_0>")].idxmax())
max_rating_per_film = int(counts_yearly[("averageRating","median")].idxmax())

plt.figure(figsize=(24,12))

plt.subplot(1,2,1)
ax =counts_yearly[("averageRating","median")].plot()
ax.annotate(max_rating_per_film,xy=(max_rating_per_film,counts_yearly[("averageRating","median")].max()),
            xytext=(1960,6.6),arrowprops=dict(shrink=0.05,color="sandybrown",width=2))
plt.title("Average Rating per Year",fontweight="bold")

plt.subplot(1,2,2)
ax = counts_yearly[("numVotes","<lambda_0>")].plot()
ax.annotate(max_count_year_per_film,xy=(max_count_year_per_film,counts_yearly[("numVotes","<lambda_0>")].max()),
            xytext=(1960,6600),arrowprops=dict(shrink=0.05,color="sandybrown",width=2))
plt.title("Average Number of Voters per Year per Film",fontweight="bold")

plt.show()

# %%
use = basics[basics.runtimeMinutes.notnull()]
use["runtimeMinutes"] = use.runtimeMinutes.astype(int)
use.sort_values(by="runtimeMinutes",ascending=False).head(10)
# Out:
#              tconst titleType                     primaryTitle  \
# 7975732   tt8273150     movie                        Logistics
# 5991910   tt3854496     movie                         Ambiancé
# 2236838  tt12277054     movie  Carnets Filmés (Liste Complète)
# 5481874   tt2659636     movie             Modern Times Forever
# 1439512  tt10844900     movie                               Qw
# 5334484   tt2355497     movie                     Beijing 2003
# 4342099  tt16226132     movie                          Soldier
# 6531504   tt5068890     movie                          Hunger!
# 6561199   tt5136218     movie                       London EC1
# 271971    tt0284020     movie            The Cure for Insomnia
#
#                            originalTitle  startYear  endYear  runtimeMinutes  \
# 7975732                        Logistics       2012      NaN           51420
# 5991910                         Ambiancé       2020      NaN           43200
# ...

# %%
rt = use.runtimeMinutes[use.runtimeMinutes<300]
mean_rt,median_rt,mode_rt = rt.mean(),rt.median(),rt.mode()[0]

plt.figure(figsize=(24,12))
sns.distplot(rt,kde_kws=dict(bw=2))
plt.gca().axvline(mean_rt,label="mean",color=sns.color_palette("Set2")[1],ymax=0.1)
plt.gca().axvline(median_rt,label="median",color=sns.color_palette("Set2")[2],ymax=0.2)
plt.gca().axvline(mode_rt,label="mode",color=sns.color_palette("Set2")[3],ymax=0.3)
plt.text(mean_rt+2,0.0025,f"Mean: {int(mean_rt)}")
plt.text(median_rt+2,0.006,f"Median: {int(median_rt)}")
plt.text(mode_rt+2,0.0085,f"Mode: {int(mode_rt)}")
plt.legend()
plt.show()

# %%
# top 20 movies with the highest voter count

merged = pd.merge(ratings,basics,on="tconst",how="right").sort_values(by="numVotes",ascending=False)
merged[["numVotes","primaryTitle","startYear"]].iloc[:20,:]
# Out:
#           numVotes                                       primaryTitle  \
# 73300  2550879.000                           The Shawshank Redemption
# 174884 2501585.000                                    The Dark Knight
# 251667 2240118.000                                          Inception
# 84913  2008263.000                                         Fight Club
# 72326  1968554.000                                       Forrest Gump
# 73105  1961407.000                                       Pulp Fiction
# 83459  1839670.000                                         The Matrix
# 79269  1779970.000  The Lord of the Rings: The Fellowship of the Ring
# 93287  1758035.000      The Lord of the Rings: The Return of the King
# 43448  1754988.000                                      The Godfather
# 184849 1695889.000                                       Interstellar
# 247357 1621375.000                              The Dark Knight Rises
# ...

# %%
# top 300 movies with the highest average rating

top300 = merged[merged.numVotes>25000].sort_values(by="averageRating",ascending=False).head(300)

# %%
# bottom 20 movies with the lowest average rating

merged[merged.numVotes>25000].sort_values(by="averageRating",ascending=True).head(20)
# Out:
#             tconst  averageRating   numVotes titleType  \
# 424425   tt7221896          1.000  38764.000     movie
# 434233   tt7886848          1.100  93845.000     movie
# 405480   tt6038600          1.200  38549.000     movie
# 404565   tt5988370          1.400  73215.000     movie
# 265778  tt14723224          1.500  37020.000     movie
# 290614   tt1702443          1.700  76204.000     movie
# 209275  tt10888594          1.800 175135.000     movie
# 37474    tt0060666          1.800  36034.000     movie
# 183615   tt0804492          1.900  38097.000     movie
# 427674   tt7431594          1.900  45462.000     movie
# 126193   tt0270846          1.900  30873.000     movie
# 227323   tt1213644          1.900  90472.000     movie
# 374709   tt4458206          2.000  27561.000     movie
# 140415   tt0317676          2.100  37061.000     movie
# 146136   tt0339034          2.100  26381.000     movie
# 151506   tt0362165          2.200  55512.000     movie
# ...

# %%
# average rating average (median) by genre


merged_temp = merged[merged.genres.notnull()]
vec = CountVectorizer(token_pattern='(?u)\\b[\\w-]+\\b', analyzer='word').fit(merged_temp.genres)
bag_of_genres = pd.DataFrame(vec.transform(merged_temp.genres).todense(),
                             columns=vec.get_feature_names(),index=merged_temp.index)
merged_temp = pd.concat([merged_temp,bag_of_genres],axis=1)

rating_counts_means = pd.DataFrame([[merged_temp.averageRating[merged_temp[i]==1].median(),merged_temp[i].sum()] 
 for i in vec.get_feature_names()],columns=["median","count"],index=vec.get_feature_names()).sort_values("median",ascending=False)

plt.figure(figsize=(7,8))
sns.barplot(y=rating_counts_means.index,x=rating_counts_means["median"],orient="h")
for i,counts in enumerate(rating_counts_means["count"]):
    plt.text(0.5,i+0.25,f"{counts:>5} films")
    plt.text(rating_counts_means["median"][i],i+0.25,rating_counts_means["median"][i])
plt.show()

# %%
# relation between rating and runtime

use = merged_temp[merged_temp.numVotes>1000]
use["runtimeMinutes"] = pd.to_numeric(use.runtimeMinutes)
[groups,edges] = pd.qcut(use.runtimeMinutes,10,precision=0,retbins=True)
ratings_avg = use.groupby(groups).agg({"averageRating":np.median})
sns.boxplot(y=groups,x="averageRating",data=use,orient="h",showfliers=False)
for i,rate in enumerate(ratings_avg["averageRating"]):
    plt.text(rate+0.1,i+0.2,rate)
plt.show()

# %%
df_movies = pd.merge( pd.merge(top300, principals, on='tconst'), name, on="nconst")
# Out:
#       tconst  averageRating    numVotes titleType              primaryTitle  \
# 0  tt0111161          9.300 2550879.000     movie  The Shawshank Redemption
# 1  tt0114369          8.600 1564190.000     movie                     Se7en
# 2  tt0120689          8.600 1240835.000     movie            The Green Mile
# 3  tt0111161          9.300 2550879.000     movie  The Shawshank Redemption
# 4  tt0111161          9.300 2550879.000     movie  The Shawshank Redemption
#
#               originalTitle  startYear  endYear  runtimeMinutes  \
# 0  The Shawshank Redemption       1994      NaN             142
# 1                     Se7en       1995      NaN             127
# 2            The Green Mile       1999      NaN             189
# 3  The Shawshank Redemption       1994      NaN             142
# 4  The Shawshank Redemption       1994      NaN             142
#
#                 genres  ordering     nconst category  job  \
# 0                Drama        10  nm0290358   editor  NaN
# ...

# %%
df_movies['birthYear'] = df_movies['birthYear'].astype(int, errors='ignore')

# %%
df_movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2916 entries, 0 to 2915
# Data columns (total 20 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   tconst             2916 non-null   object
#  1   averageRating      2916 non-null   float64
#  2   numVotes           2916 non-null   float64
#  3   titleType          2916 non-null   object
#  4   primaryTitle       2916 non-null   object
#  5   originalTitle      2916 non-null   object
#  6   startYear          2916 non-null   int32
#  7   endYear            0 non-null      float64
#  8   runtimeMinutes     2916 non-null   int32
#  9   genres             2916 non-null   object
#  10  ordering           2916 non-null   int64
#  11  nconst             2916 non-null   object
#  12  category           2916 non-null   object
#  13  job                971 non-null    object
#  14  characters         1181 non-null   object
#  15  primaryName        2916 non-null   object
# ...

# %%
df_movies.describe()
# Out:
#        averageRating    numVotes  startYear  endYear  runtimeMinutes  \
# count       2916.000    2916.000   2916.000    0.000        2916.000
# mean           8.329  459314.182   1990.041      NaN         131.821
# std            0.242  513989.164     25.392      NaN          33.752
# min            8.100   25076.000   1920.000      NaN          25.000
# 25%            8.200   64873.000   1974.000      NaN         108.750
# 50%            8.300  234502.000   1998.000      NaN         129.000
# 75%            8.400  785304.000   2012.000      NaN         152.000
# max            9.300 2550879.000   2021.000      NaN         321.000
#
#        ordering  birthYear  deathYear
# count  2916.000   2246.000    928.000
# mean      5.465   1940.746   1988.816
# std       2.851     32.559     32.884
# min       1.000   1414.000   1471.000
# 25%       3.000   1921.000   1977.000
# 50%       5.000   1944.000   1993.000
# 75%       8.000   1964.000   2007.250
# ...

# %%
df_movies.head(100)
# Out:
#         tconst  averageRating    numVotes titleType              primaryTitle  \
# 0    tt0111161          9.300 2550879.000     movie  The Shawshank Redemption
# 1    tt0114369          8.600 1564190.000     movie                     Se7en
# 2    tt0120689          8.600 1240835.000     movie            The Green Mile
# 3    tt0111161          9.300 2550879.000     movie  The Shawshank Redemption
# 4    tt0111161          9.300 2550879.000     movie  The Shawshank Redemption
# 5    tt0114369          8.600 1564190.000     movie                     Se7en
# 6    tt0105695          8.200  400346.000     movie                Unforgiven
# 7    tt0111161          9.300 2550879.000     movie  The Shawshank Redemption
# 8    tt0111161          9.300 2550879.000     movie  The Shawshank Redemption
# 9    tt0111161          9.300 2550879.000     movie  The Shawshank Redemption
# 10   tt0120689          8.600 1240835.000     movie            The Green Mile
# ...

# %%
df_movie_director = df_movies[df_movies.category=="director"]

# %%
df_movie_director = df_movie_director.drop(['category','job','characters','endYear','titleType','ordering'],axis=1)

# %%
df_movie_director[df_movie_director.birthYear.isnull()]
# Out:
#           tconst  averageRating    numVotes  \
# 31    tt15097216          9.300  175864.000
# 75    tt10189514          9.100  107744.000
# 85     tt5354160          9.100   25645.000
# 92     tt2592910          9.100   45703.000
# 163   tt11989890          9.000   30779.000
# 164   tt11989890          9.000   30779.000
# 378   tt10280296          8.700   36579.000
# 398    tt5813916          8.700  107606.000
# 440   tt10295212          8.700  113506.000
# 465    tt9477520          8.600   25350.000
# 597    tt0103767          8.600   38286.000
# 598    tt0770802          8.500   35253.000
# 771    tt7019842          8.500   27776.000
# 956    tt2380307          8.400  464501.000
# 998    tt4633694          8.400  473115.000
# 1000   tt4633694          8.400  473115.000
# 1023   tt7060344          8.400   38104.000
# 1035   tt6316138          8.400   38320.000
# 1108   tt5074352          8.400  178804.000
# 1109   tt9052870          8.300   47975.000
# ...

# %%
df_movie_director.to_csv("../02DerivedData/movie_director.csv",index=False)

# %% [markdown]
# # MetaCritic

# %%
mc_movie = pd.read_csv('../01PrimaryData/MetaCritic/movies.csv')
mc_movie.head()
# Out:
#            movie_title release_date                         genre  meta_mixed  \
# 0  Anatomy of a Murder     1-Jul-59  Drama,Mystery,Thriller,Crime           0
# 1     Bringing Up Baby    18-Feb-38         Comedy,Romance,Family           0
# 2           After Life    12-May-99                 Drama,Fantasy           0
# 3              Gavagai     3-Aug-18                         Drama           1
# 4          The Hustler    25-Sep-61                   Drama,Sport           1
#
#    meta_negative  meta_positive  metascore user_mixed user_negative  \
# 0              0             15         95          0             0
# 1              1             16         91          1             0
# 2              0             19         91          0             2
# 3              0              6         91          0             1
# 4              0             17         90          0             0
#
#   user_positive userscore
# 0             3       tbd
# 1             2       tbd
# ...

# %%
mc_review = pd.read_csv('../01PrimaryData/MetaCritic/reviews.csv')
mc_review.head()
# Out:
#           critic_name                 media    movie_title review_date  \
# 0       M. E. Russell    Portland Oregonian  Hustle & Flow         NaN
# 1     Owen Gleiberman  Entertainment Weekly  Hustle & Flow         NaN
# 2        Ann Hornaday       Washington Post  Hustle & Flow         NaN
# 3  Stephanie Zacharek                 Salon  Hustle & Flow         NaN
# 4        Jami Bernard   New York Daily News  Hustle & Flow         NaN
#
#    individual_meta_score                                               text
# 0                    100  The writing, acting and filmmaking make Hustle...
# 1                     91  The home-studio recording sequences in Hustle ...
# 2                     90  The performances are accomplished, but the rea...
# 3                     90  In a world of movies that try far too hard to ...
# 4                     88  The feel-good movie of the summer. And the son...

# %%
mc_review.describe(include='all')
# Out:
#         critic_name               media    movie_title review_date  \
# count        213860              232245         246955      105710
# unique         1006                  77          12029        3096
# top     Roger Ebert  The New York Times  The Lion King   29-Jun-17
# freq           4763               11742             83         194
# mean            NaN                 NaN            NaN         NaN
# std             NaN                 NaN            NaN         NaN
# min             NaN                 NaN            NaN         NaN
# 25%             NaN                 NaN            NaN         NaN
# 50%             NaN                 NaN            NaN         NaN
# 75%             NaN                 NaN            NaN         NaN
# max             NaN                 NaN            NaN         NaN
#
#         individual_meta_score                                text
# count                246.955k                              233198
# ...

# %% [markdown]
# # MovieLens

# %%
import os
import random
import zipfile
import re
import math
import urllib


# essentials
import numpy as np
import pandas as pd
import tensorflow as tf


#viz
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.manifold import TSNE
from tqdm import tqdm_notebook

# import our skipgram model from local
#from skip_gram_model import SkipGramModel

# %%
import math
import tensorflow.compat.v1 as tf
tf.disable_v2_behavior()


class SkipGramModel(object):

    """Word2Vec ( Mikolov et al.) using skipgram model. Can be used on non-word text
    inputs too!
    
    Attributes:
        b (tf.Variable): bias for nce loss
        batch_size (int): size of training batch
        embedding_dims (int): size of embedding
        embeddings (tf.Variable): embedding object for text/items
        init_op (tf.global_variables_initializer): this is tf.global_variables_initializer 
            to initilize variable in the model. call as model.init_op() in session.
        loss (TYPE): model loss function - mean NCE loss
        lr (TYPE): learning rate passed to optimizer 
        n_samples (int): number of negative samples based on batch size and
            the sample_factor parameter.
        normalized_embeddings (tensor): normalized embeddings
        optimize (tensor): optimization step
        optimizer (tf.train.Optimizer): optimizer default is adagrad
        saver (tf.train.Saver): tf.train.Saver object call in session after model.init_op().
        similarity (tensor): measure similarity on val_x
        val_data (np.array, 'int32'): indexes of validation samples to evaluate similarity on during training
        val_x (tf.Placeholder): from val_data
        vocab_size (int): size of 'vocabulary'
        w (tf.Variable): weights for nce loss
        x (tf.Placeholder): placeholder for input data
        y (tf.Placeholder): placeholder for input labels
    """
    
    def __init__(self, vocab_size, val_data, embedding_dims=256, batch_size=128, sample_factor=1, lr=1., optimizer=tf.train.AdagradOptimizer):
        
        self.embedding_dims = embedding_dims
        self.vocab_size = vocab_size
        self.batch_size = batch_size
        self.optimizer = optimizer
        self.val_data = val_data

        
        #number of negative samples (batch * sample factors)
        self.n_samples = int(round(sample_factor  * self.batch_size))
        self.lr = lr 
        self.init_model()
        
    @staticmethod
    def embed(embeddings, inp):
        return tf.nn.embedding_lookup(embeddings, inp)
    
    def mean_nce_loss(self, inp):
        return tf.reduce_mean(tf.nn.nce_loss(weights=self.w,
                                                 biases=self.b,
                                                 labels=self.y,
                                                 inputs=inp,
                                                 num_sampled=self.n_samples,
                                                 num_classes=self.vocab_size), name='loss')
    
    def normalize_embeddings(self):
        norm = tf.sqrt(tf.reduce_sum(tf.square(self.embeddings), 1, keep_dims=True))
        normalized_embeddings = self.embeddings / norm
        self.normalized_embeddings = normalized_embeddings
    
    def get_similarity(self, t):
        pred_embeddings = self.embed(self.normalized_embeddings, t)
        sim = tf.matmul(pred_embeddings, self.normalized_embeddings, transpose_b=True)
        return sim
    

    def init_model(self):
        # Input data.
        self.x = tf.placeholder(tf.int32, shape=[self.batch_size], name='x')
        self.y = tf.placeholder(tf.int32, shape=[self.batch_size, 1], name='y')
        self.val_x = tf.constant(self.val_data, name='val_x')
        # embedding var

        with tf.device('/cpu:0'):
            self.embeddings = tf.Variable(tf.random_uniform([self.vocab_size, self.embedding_dims], -1.0, 1.0))
            # nce loss weights and biases
            self.w = tf.Variable(tf.truncated_normal([self.vocab_size, self.embedding_dims],
                                                    stddev=1.0 / math.sqrt(self.embedding_dims)))
            self.b = tf.Variable(tf.zeros([self.vocab_size]))

        embedded = self.embed(self.embeddings, self.x)
        self.loss = self.mean_nce_loss(embedded)
        self.optimize = self.optimizer(self.lr).minimize(self.loss, name='optimize')

        self.normalize_embeddings()
        self.similarity = self.get_similarity(self.val_x)
        self.init_op = tf.global_variables_initializer
        self.saver = tf.train.Saver

# %%
data_dir = '../01PrimaryData/MovieLens/'
ml_ratings = pd.read_csv(os.path.join(data_dir, 'ratings.csv'))
ml_movies = pd.read_csv(os.path.join(data_dir, 'movies.csv'))

# %%
ml_movies.head()
# Out:
#    movieId                               title  \
# 0        1                    Toy Story (1995)
# 1        2                      Jumanji (1995)
# 2        3             Grumpier Old Men (1995)
# 3        4            Waiting to Exhale (1995)
# 4        5  Father of the Bride Part II (1995)
#
#                                         genres
# 0  Adventure|Animation|Children|Comedy|Fantasy
# 1                   Adventure|Children|Fantasy
# 2                               Comedy|Romance
# 3                         Comedy|Drama|Romance
# 4                                       Comedy

# %%
ml_ratings.head()
# Out:
#    userId  movieId  rating   timestamp
# 0       1        2     3.5  1112486027
# 1       1       29     3.5  1112484676
# 2       1       32     3.5  1112484819
# 3       1       47     3.5  1112484727
# 4       1       50     3.5  1112484580

# %%
counts = ml_ratings.movieId.value_counts()

# filter out movies only in dataset once
ratings = ml_ratings.loc[ml_ratings.movieId.isin(counts.loc[(counts > 1)].index)]

# %%
# repalce movieId with an integer for its frequency
# make a dictionary of old_id2 moviename
id_2_movie_name = dict(ml_movies[['movieId', 'title']].values)

# make a dictionary mapping of new id (based on frequency) and the moviename
# by convention we'll let reserve 0 in case we want to use this for masking
# in the future...
id2idx = {k:i+1 for i, (k, v) in enumerate(ratings.movieId.value_counts().items())}
# id2idxmake a dictionary of to new moviename
dictionary = {id2idx[k]: id_2_movie_name[k] for k in id2idx}
id2idx[0] = 'null'
dictionary[0] = 'null'
reverse_dictionary = {v:k for k,v in dictionary.items()}

ratings = ratings.loc[ratings.movieId.isin(id2idx)]
ratings.movieId = ratings.movieId.apply(lambda x : id2idx[x])

# delete the id_2_movie_name & the movies frame we won't need them anymore
del id_2_movie_name
del ml_movies
del ml_ratings

# %%
movie_series = pd.Series(dictionary)

def fuzzy_movie_lookup(movie_str, dat=movie_series):
    """query a movie name using a regex string
    return all matches and their indexes.
    """
    return dat.loc[dat.str.contains(movie_str, flags=re.IGNORECASE)]

# %%
# sort each user-movie choices by rating, then by timestamp

data =[]

for key, chunk in ratings.groupby('userId'):
    data.append(chunk.sort_values(['rating', 'timestamp']).movieId.values)

# %%
def get_batch(seq, rel_window_size=.2):
    """get a batch of data for a single user sequence.
    data will be chosen randomly from within a moving 
    window relative to the size of the entire sequence. 
    with the initial point chosen at random.
    """
    window = math.floor(len(seq) * rel_window_size) +1
    x = []
    y = []
    i = random.randint(0, len(seq)-1)
    for _ in range(batch_size):
        x.append(seq[i])
        moves = list(range(max(i-window, 0), i)) + list(range(i+1, min((i+window + 1, len(seq)))))
        j = random.choice(moves)
        y.append(seq[j])
        i = j
    return x, y            
            
def gen_batch(data, batch_size, rel_window_size=.2, shuffle=True):
    """make a generator for data using each 'user' as a document."""
    while True:
        for doc_index, doc in enumerate(data):
            x, y = get_batch(doc, rel_window_size)
            yield np.array(x, 'int32'), np.expand_dims(np.array(y,'int32'), 1)
        if shuffle:
            random.shuffle(data)

# %%
val_films = ['Little Mermaid, The (1989)', 
             'Princess Mononoke (Mononoke-hime) (1997)', 
             'Three Musketeers, The (1993)',
             'Addams Family Values (1993)', 
             'NeverEnding Story, The (1984)',
             'Gone with the Wind (1939)',
             'Police Academy (1984)',
             'Transformers (2007)',
             'Streetcar Named Desire, A (1951)',
             'Star Trek: First Contact (1996)',
             'Miracle on 34th Street (1994)',
             'Third Man, The (1949)',
             'Last Samurai, The (2003)',
             'Sleeper (1973)',
             'Poltergeist (1982)'
            ]

val_ids = [reverse_dictionary[s] for s in val_films]

# %%
print(fuzzy_movie_lookup(r'Forbidden Zone'))
val_ids.append(9030)
# Out:
# 6781    Spacehunter: Adventures in the Forbidden Zone ...
# 9021                                Forbidden Zone (1980)
# dtype: object

# %%
print(fuzzy_movie_lookup(r'Hausu'))
val_ids.append(8787)
# Out:
# 8781    House (Hausu) (1977)
# dtype: object

# %%
print(fuzzy_movie_lookup(r'Solaris')) 
# we want the original tarkovsky version for sure!
val_ids.append(1946)
# Out:
# 1616               Solaris (2002)
# 1946    Solaris (Solyaris) (1972)
# dtype: object

# %%
print(fuzzy_movie_lookup(r'shadows of our forgotten ancestors')) 
# we want the original tarkovsky version for sure!
val_ids.append(11060)
# Out:
# 11106    Shadows of Our Forgotten Ancestors (Tini zabut...
# dtype: object

# %%
val_set = np.array(val_ids, 'int32')

# %% [markdown]
# #### Build Model

# %%
# valid_examples = np.array(random.sample(range(1, valid_window+1), valid_size))
vocab_size = len(dictionary)
batch_size = 128
embedding_size = 256  # Dimension of the embedding vector.
val_size =len(val_set)

lr = 1.


model = SkipGramModel(vocab_size, val_set, embedding_dims=256, 
                      batch_size=batch_size, sample_factor=1., lr=lr, optimizer= tf.train.AdagradOptimizer)
# Out:
# WARNING:tensorflow:From C:\Users\mgu3\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\training\adagrad.py:76: calling Constant.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From C:\Users\mgu3\Anaconda3\envs\tf\lib\site-packages\tensorflow\python\util\dispatch.py:206: calling reduce_sum_v1 (from tensorflow.python.ops.math_ops) with keep_dims is deprecated and will be removed in a future version.
# Instructions for updating:
# keep_dims is deprecated, use keepdims instead

# %% [markdown]
# #### Training

# %%
# create the data generator
data_gen = gen_batch(data, batch_size, rel_window_size = .2, shuffle=True)
steps_per_cycle = (len(data) // batch_size)
n_iter = 200 # number of full cycles through data
num_steps = int(n_iter * steps_per_cycle)
lstep = steps_per_cycle # steps to show average loss
vstep = steps_per_cycle * 20  # steps to show val data

def show_n_similar(item, sim, k=5):                
    item_name = dictionary[item]
    nearest = (-sim).argsort()[1:k + 1]
    log_str = '\nNearest to - {}:\n'.format(item_name)
    for k in range(k):
        log_str += '\t{},\n'.format(dictionary[nearest[k]])
    print(log_str)

    
losses = []

with tf.Session() as sess:
    sess.run(model.init_op())
    print('initialized ...')
    # set so we can watch average loss during training

    for step in tqdm_notebook(range(num_steps)):
        batch_inputs, batch_labels = next(data_gen)
        feed_dict = {model.x: batch_inputs, 
                     model.y: batch_labels}
        
        _, loss_ = sess.run([model.optimize, model.loss], feed_dict=feed_dict)
        losses.append(loss_) # for plotting
        
    sim = model.similarity.eval()

    for i in range(len(val_ids)):
        show_n_similar(model.val_data[i], sim[i], k=5)
    
    out_embeddings = model.normalized_embeddings.eval()


#     uncomment to save model to a directory 'logs'

    saver = model.saver()       
    spath = 'movie2vec_{}.ckpt'
    saver.save(sess=sess, save_path=spath.format(step))
    print('Model saved in file: {}'.format(spath))
# Out:
# initialized ...
# C:\Users\mgu3\AppData\Local\Temp\ipykernel_14364\1934267299.py:25: TqdmDeprecationWarning: This function will be removed in tqdm==5.0.0
# Please use `tqdm.notebook.tqdm` instead of `tqdm.tqdm_notebook`
#   for step in tqdm_notebook(range(num_steps)):
#   0%|          | 0/216200 [00:00<?, ?it/s]
# Nearest to - Little Mermaid, The (1989):
# 	Mary Poppins (1964),
# 	Grease (1978),
# 	Rocky Horror Picture Show, The (1975),
# 	Mask of Zorro, The (1998),
# 	Pleasantville (1998),
#
#
# Nearest to - Princess Mononoke (Mononoke-hime) (1997):
# 	Howl's Moving Castle (Hauru no ugoku shiro) (2004),
# 	Spirited Away (Sen to Chihiro no kamikakushi) (2001),
# 	Akira (1988),
# 	My Neighbor Totoro (Tonari no Totoro) (1988),
# 	Laputa: Castle in the Sky (Tenkû no shiro Rapyuta) (1986),
#
#
# Nearest to - Three Musketeers, The (1993):
# 	Robin Hood: Men in Tights (1993),
# 	So I Married an Axe Murderer (1993),
# 	Last Action Hero (1993),
# 	First Knight (1995),
# ...

# %% [markdown]
# we can save the final embeddings along with our movie and index dictionarys and load these as weights for the item embedding half of a customer x model based model or compute user similarities entirely based on their product reccomendations, which in a situation where the number of users grows at a higher rate than the number of products is very useful.

# %%
# Plot the movie space embeddings

def plot(embeddings, labels):
    plt.figure(figsize=(20, 15)) 
    for i, label in enumerate(labels):
        x, y = embeddings[i, :]
        plt.scatter(x, y)
        plt.annotate(label, xy=(x, y))
        
        
r = np.arange(1, 200+1)
tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000, learning_rate=100)
t = tsne.fit_transform(out_embeddings[r, :])
plot(t, [dictionary[i] for i in r])
# Out:
# C:\Users\mgu3\Anaconda3\envs\tf\lib\site-packages\sklearn\manifold\_t_sne.py:982: FutureWarning: The PCA initialization in TSNE will change to have the standard deviation of PC1 equal to 1e-4 in 1.2. This will ensure better convergence.
#   warnings.warn(
